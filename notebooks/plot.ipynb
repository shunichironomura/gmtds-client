# %%
import json

# %%
with open("../data.json") as f:
    json_data = json.load(f)

# %%
import numpy as np

data = np.asarray(json_data).reshape(359, 180).transpose()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data, cmap="hot", interpolation="nearest")
